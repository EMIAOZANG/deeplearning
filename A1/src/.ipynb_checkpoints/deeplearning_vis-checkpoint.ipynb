# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#draw augment/no augment comparision
plt.style.use('ggplot')
df = pd.read_csv('~/Downloads/final - Sheet2.csv')

# %%
df.plot()

# %%
import matplotlib
# %matplotlib inline

# %%
df1 = df['Baseline']
df1.name = 'Integrated'
print type(df1),df1
ax = df.plot(title="Prediction Accuracy vs. nepochs")
df1.plot(linewidth=3.3)
plt.xlabel("Epochs")
plt.ylabel("Accuracy(%)")
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
# Out:
# <class 'pandas.core.series.Series'> 0    85.55
# 1    93.85
# 2    95.60
# 3    96.75
# 4    97.65
# 5    98.40
# 6    98.75
# 7    99.10
# 8    98.90
# 9    99.35
# Name: Integrated, dtype: float64
